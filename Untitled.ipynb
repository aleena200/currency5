# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders
# Out:
# 2025-02-22 06:02:42.158024: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-22 06:02:42.256464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740222162.300563   85372 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740222162.315594   85372 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 06:02:42.416153: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
splitfolders.ratio(r"/home/user/Ajaycurrency4/Currency_Dataset", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 0 files [00:00, ? files/s]
#
# Copying files: 13 files [00:00, 124.74 files/s]
#
# Copying files: 33 files [00:00, 167.92 files/s]
#
# Copying files: 53 files [00:00, 179.50 files/s]
#
# Copying files: 74 files [00:00, 188.45 files/s]
#
# Copying files: 93 files [00:00, 175.64 files/s]
#
# Copying files: 111 files [00:00, 125.03 files/s]
#
# Copying files: 127 files [00:00, 132.81 files/s]
#
# Copying files: 142 files [00:01, 119.33 files/s]
#
# Copying files: 158 files [00:01, 125.38 files/s]
#
# Copying files: 173 files [00:01, 130.02 files/s]
#
# Copying files: 187 files [00:01, 108.32 files/s]
#
# Copying files: 205 files [00:01, 124.11 files/s]
#
# Copying files: 219 files [00:01, 104.93 files/s]
#
# Copying files: 231 files [00:01, 102.77 files/s]
#
# Copying files: 251 files [00:01, 125.23 files/s]
#
# Copying files: 270 files [00:02, 139.64 files/s]
#
# Copying files: 286 files [00:02, 116.71 files/s]
#
# Copying files: 304 files [00:02, 130.51 files/s]
#
# Copying files: 319 files [00:02, 112.23 files/s]
#
# Copying files: 339 files [00:02, 131.71 files/s]
#
# Copying files: 354 files [00:02, 115.66 files/s]
#
# Copying files: 373 files [00:02, 132.11 files/s]
#
# Copying files: 388 files [00:03, 112.05 files/s]
#
# Copying files: 405 files [00:03, 123.65 files/s]
#
# Copying files: 419 files [00:03, 105.53 files/s]
#
# Copying files: 437 files [00:03, 120.42 files/s]
#
# Copying files: 451 files [00:03, 109.39 files/s]
#
# Copying files: 467 files [00:03, 119.91 files/s]
#
# Copying files: 481 files [00:03, 100.91 files/s]
#
# Copying files: 500 files [00:04, 120.05 files/s]
#
# Copying files: 514 files [00:04, 121.96 files/s]
#
# Copying files: 528 files [00:04, 107.57 files/s]
#
# Copying files: 548 files [00:04, 128.42 files/s]
#
# Copying files: 563 files [00:04, 116.12 files/s]
#
# Copying files: 580 files [00:04, 122.93 files/s]
#
# Copying files: 594 files [00:04, 103.56 files/s]
#
# Copying files: 606 files [00:05, 75.68 files/s]
#
# Copying files: 626 files [00:05, 97.73 files/s]
#
# Copying files: 646 files [00:05, 117.62 files/s]
#
# Copying files: 667 files [00:05, 137.53 files/s]
#
# Copying files: 686 files [00:05, 148.71 files/s]
#
# Copying files: 703 files [00:05, 137.58 files/s]
#
# Copying files: 719 files [00:05, 129.20 files/s]
#
# Copying files: 738 files [00:06, 143.11 files/s]
#
# Copying files: 754 files [00:06, 118.87 files/s]
#
# Copying files: 774 files [00:06, 136.32 files/s]
#
# Copying files: 790 files [00:06, 118.52 files/s]
#
# Copying files: 807 files [00:06, 129.01 files/s]
#
# Copying files: 822 files [00:06, 106.46 files/s]
#
# Copying files: 838 files [00:06, 116.59 files/s]
#
# Copying files: 852 files [00:07, 102.64 files/s]
#
# Copying files: 866 files [00:07, 109.33 files/s]
#
# Copying files: 881 files [00:07, 111.62 files/s]
#
# Copying files: 893 files [00:07, 103.67 files/s]
#
# Copying files: 909 files [00:07, 115.48 files/s]
#
# Copying files: 922 files [00:07, 100.19 files/s]
#
# Copying files: 941 files [00:07, 119.32 files/s]
#
# Copying files: 954 files [00:08, 96.52 files/s]
#
# Copying files: 970 files [00:08, 109.53 files/s]
#
# Copying files: 983 files [00:08, 109.66 files/s]
#
# Copying files: 995 files [00:08, 108.43 files/s]
#
# Copying files: 1011 files [00:08, 113.43 files/s]
#
# Copying files: 1023 files [00:08, 99.63 files/s]
#
# Copying files: 1039 files [00:08, 112.76 files/s]
#
# Copying files: 1051 files [00:08, 93.58 files/s]
#
# Copying files: 1067 files [00:09, 107.97 files/s]
#
# Copying files: 1080 files [00:09, 108.56 files/s]
#
# Copying files: 1092 files [00:09, 101.04 files/s]
#
# Copying files: 1109 files [00:09, 109.45 files/s]
#
# Copying files: 1121 files [00:09, 95.48 files/s]
#
# Copying files: 1139 files [00:09, 113.88 files/s]
#
# Copying files: 1152 files [00:09, 114.72 files/s]
#
# Copying files: 1165 files [00:10, 90.65 files/s]
#
# Copying files: 1182 files [00:10, 106.42 files/s]
#
# Copying files: 1194 files [00:10, 85.42 files/s]
#
# Copying files: 1204 files [00:10, 68.95 files/s]
#
# Copying files: 1213 files [00:10, 65.71 files/s]
#
# Copying files: 1221 files [00:10, 64.38 files/s]
#
# Copying files: 1229 files [00:11, 64.66 files/s]
#
# Copying files: 1236 files [00:11, 59.96 files/s]
#
# Copying files: 1244 files [00:11, 64.04 files/s]
#
# Copying files: 1251 files [00:11, 56.88 files/s]
#
# Copying files: 1259 files [00:11, 61.88 files/s]
#
# Copying files: 1266 files [00:11, 54.89 files/s]
#
# Copying files: 1275 files [00:11, 57.37 files/s]
#
# Copying files: 1281 files [00:12, 45.62 files/s]
#
# Copying files: 1287 files [00:12, 42.56 files/s]
#
# Copying files: 1297 files [00:12, 53.97 files/s]
#
# Copying files: 1309 files [00:12, 64.41 files/s]
#
# Copying files: 1317 files [00:12, 60.80 files/s]
#
# Copying files: 1324 files [00:12, 60.66 files/s]
#
# Copying files: 1331 files [00:12, 54.53 files/s]
#
# Copying files: 1340 files [00:13, 62.55 files/s]
#
# Copying files: 1347 files [00:13, 53.32 files/s]
#
# Copying files: 1355 files [00:13, 59.13 files/s]
#
# Copying files: 1362 files [00:13, 51.93 files/s]
#
# Copying files: 1372 files [00:13, 58.31 files/s]
#
# Copying files: 1379 files [00:13, 53.49 files/s]
#
# Copying files: 1387 files [00:13, 59.25 files/s]
#
# Copying files: 1394 files [00:14, 52.28 files/s]
#
# Copying files: 1402 files [00:14, 57.94 files/s]
#
# Copying files: 1409 files [00:14, 50.98 files/s]
#
# Copying files: 1419 files [00:14, 60.29 files/s]
#
# Copying files: 1426 files [00:14, 53.32 files/s]
#
# Copying files: 1435 files [00:14, 60.32 files/s]
#
# Copying files: 1442 files [00:14, 51.86 files/s]
#
# Copying files: 1450 files [00:15, 57.30 files/s]
#
# Copying files: 1457 files [00:15, 53.09 files/s]
#
# Copying files: 1464 files [00:15, 54.01 files/s]
#
# Copying files: 1470 files [00:15, 51.06 files/s]
#
# Copying files: 1483 files [00:15, 67.71 files/s]
#
# Copying files: 1491 files [00:15, 55.89 files/s]
#
# Copying files: 1506 files [00:15, 75.69 files/s]
#
# Copying files: 1516 files [00:15, 80.61 files/s]
#
# Copying files: 1525 files [00:16, 71.70 files/s]
#
# Copying files: 1535 files [00:16, 77.14 files/s]
#
# Copying files: 1544 files [00:16, 68.39 files/s]
#
# Copying files: 1555 files [00:16, 77.07 files/s]
#
# Copying files: 1564 files [00:16, 65.30 files/s]
#
# Copying files: 1578 files [00:16, 81.78 files/s]
#
# Copying files: 1588 files [00:17, 66.44 files/s]
#
# Copying files: 1596 files [00:17, 59.99 files/s]
#
# Copying files: 1603 files [00:17, 54.05 files/s]
#
# Copying files: 1610 files [00:17, 50.22 files/s]
#
# Copying files: 1627 files [00:17, 74.26 files/s]
#
# Copying files: 1652 files [00:17, 112.39 files/s]
#
# Copying files: 1666 files [00:18, 88.06 files/s]
#
# Copying files: 1678 files [00:18, 87.54 files/s]
#
# Copying files: 1689 files [00:18, 82.93 files/s]
#
# Copying files: 1699 files [00:18, 69.23 files/s]
#
# Copying files: 1714 files [00:18, 82.62 files/s]
#
# Copying files: 1724 files [00:18, 71.94 files/s]
#
# Copying files: 1736 files [00:18, 79.04 files/s]
#
# Copying files: 1745 files [00:19, 73.57 files/s]
#
# Copying files: 1756 files [00:19, 77.33 files/s]
#
# Copying files: 1765 files [00:19, 70.78 files/s]
#
# Copying files: 1778 files [00:19, 81.60 files/s]
#
# Copying files: 1788 files [00:19, 85.23 files/s]
#
# Copying files: 1797 files [00:19, 69.88 files/s]
#
# Copying files: 1812 files [00:19, 87.34 files/s]
#
# Copying files: 1822 files [00:20, 71.75 files/s]
#
# Copying files: 1835 files [00:20, 80.13 files/s]
#
# Copying files: 1844 files [00:20, 70.30 files/s]
#
# Copying files: 1854 files [00:20, 76.05 files/s]
#
# Copying files: 1863 files [00:20, 66.77 files/s]
#
# Copying files: 1871 files [00:20, 62.26 files/s]
#
# Copying files: 1878 files [00:20, 60.27 files/s]
#
# Copying files: 1886 files [00:21, 62.73 files/s]
#
# Copying files: 1893 files [00:21, 52.35 files/s]
#
# Copying files: 1903 files [00:21, 61.70 files/s]
#
# Copying files: 1910 files [00:21, 54.61 files/s]
#
# Copying files: 1918 files [00:21, 57.01 files/s]
#
# Copying files: 1925 files [00:21, 53.75 files/s]
#
# Copying files: 1933 files [00:21, 55.40 files/s]
#
# Copying files: 1939 files [00:22, 47.95 files/s]
#
# Copying files: 1945 files [00:22, 40.36 files/s]
#
# Copying files: 1950 files [00:22, 39.36 files/s]
#
# Copying files: 1955 files [00:22, 37.26 files/s]
#
# Copying files: 1959 files [00:22, 37.07 files/s]
#
# Copying files: 1963 files [00:22, 37.27 files/s]
#
# Copying files: 1979 files [00:22, 66.92 files/s]
#
# Copying files: 1997 files [00:23, 92.98 files/s]
#
# Copying files: 2007 files [00:23, 70.57 files/s]
#
# Copying files: 2016 files [00:23, 69.02 files/s]
#
# Copying files: 2024 files [00:23, 64.12 files/s]
#
# Copying files: 2031 files [00:23, 58.63 files/s]
#
# Copying files: 2038 files [00:23, 58.17 files/s]
#
# Copying files: 2045 files [00:23, 58.23 files/s]
#
# Copying files: 2052 files [00:24, 53.97 files/s]
#
# Copying files: 2060 files [00:24, 59.08 files/s]
#
# Copying files: 2067 files [00:24, 52.07 files/s]
#
# Copying files: 2074 files [00:24, 52.71 files/s]
#
# Copying files: 2080 files [00:24, 51.60 files/s]
#
# Copying files: 2089 files [00:24, 60.67 files/s]
#
# Copying files: 2096 files [00:24, 54.49 files/s]
#
# Copying files: 2103 files [00:25, 58.02 files/s]
#
# Copying files: 2110 files [00:25, 59.33 files/s]
#
# Copying files: 2117 files [00:25, 54.68 files/s]
#
# Copying files: 2125 files [00:25, 59.17 files/s]
#
# Copying files: 2132 files [00:25, 55.30 files/s]
#
# Copying files: 2141 files [00:25, 60.95 files/s]
#
# Copying files: 2148 files [00:25, 53.22 files/s]
#
# Copying files: 2156 files [00:25, 56.15 files/s]
#
# Copying files: 2163 files [00:26, 59.02 files/s]
#
# Copying files: 2170 files [00:26, 49.91 files/s]
#
# Copying files: 2179 files [00:26, 56.67 files/s]
#
# Copying files: 2186 files [00:26, 59.36 files/s]
#
# Copying files: 2193 files [00:26, 53.46 files/s]
#
# Copying files: 2199 files [00:26, 52.70 files/s]
#
# Copying files: 2206 files [00:26, 55.53 files/s]
#
# Copying files: 2212 files [00:27, 50.33 files/s]
#
# Copying files: 2219 files [00:27, 52.77 files/s]
#
# Copying files: 2225 files [00:27, 46.12 files/s]
#
# Copying files: 2230 files [00:27, 43.21 files/s]
#
# Copying files: 2235 files [00:27, 41.17 files/s]
#
# Copying files: 2240 files [00:27, 38.51 files/s]
#
# Copying files: 2244 files [00:27, 37.84 files/s]
#
# Copying files: 2260 files [00:28, 80.42 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 6 folder and 0 images in output/train
# 0 folder and 300 images in output/train/50_new
# 0 folder and 300 images in output/train/10_new
# 0 folder and 300 images in output/train/200_new
# 0 folder and 195 images in output/train/500_new
# 0 folder and 300 images in output/train/100_new
# 0 folder and 300 images in output/train/20_new
# 6 folder and 0 images in output/test
# 0 folder and 20 images in output/test/50_new
# 0 folder and 20 images in output/test/10_new
# 0 folder and 20 images in output/test/200_new
# 0 folder and 13 images in output/test/500_new
# 0 folder and 20 images in output/test/100_new
# 0 folder and 20 images in output/test/20_new
# 6 folder and 0 images in output/val
# 0 folder and 80 images in output/val/50_new
# 0 folder and 80 images in output/val/10_new
# 0 folder and 80 images in output/val/200_new
# 0 folder and 52 images in output/val/500_new
# 0 folder and 80 images in output/val/100_new
# 0 folder and 80 images in output/val/20_new

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='10_new')
# Out:
# Image Shape : (4096, 3072, 3)

# %%
import os
import cv2
import numpy as np
import tkinter as tk
from tkinter import filedialog, messagebox
from PIL import Image, ImageTk
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import threading  # Used for running classification in the background

# --------------------------- #
# 🔹 Define Paths & Parameters
# --------------------------- #
train_dir = "output/train"
val_dir = "output/val"
input_shape = (224, 224, 3)
batch_size = 32
NUM_CLASSES = 6  # Updated number of classes

# Define explicit class order
classes_order = ["10_new", "20_new", "50_new", "100_new", "200_new", "500_new"]

# --------------------------- #
# 🔹 Data Preparation (for VGG16)
# --------------------------- #
train_datagen = ImageDataGenerator(rescale=1.0/255.0)
val_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    classes=classes_order  # Explicit order for training
)

val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    classes=classes_order  # Explicit order for validation
)

print("Training class indices:", train_data.class_indices)
print("Validation class indices:", val_data.class_indices)

# --------------------------- #
# 🔹 Function to Create VGG16 Model
# --------------------------- #
def create_vgg16_model():
    base_model = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze pre-trained layers

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation="softmax")(x)  # Ensure correct number of classes

    model = Model(inputs=base_model.input, outputs=output)
    return model

# --------------------------- #
# 🔹 Train and Save VGG16 Model (if not exists)
# --------------------------- #
vgg16_model_path = "vgg16_model.h5"

if not os.path.exists(vgg16_model_path):
    print("Training VGG16 Model... 🚀")
    vgg16_model = create_vgg16_model()
    vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                        loss="categorical_crossentropy",
                        metrics=["accuracy"])
    
    vgg16_model.fit(train_data, epochs=30, validation_data=val_data)
    vgg16_model.save(vgg16_model_path)
    print(f"✅ VGG16 Model saved as '{vgg16_model_path}'.")
else:
    print(f"✅ Found existing model '{vgg16_model_path}', skipping training.")

# Load the trained model
vgg16_model = create_vgg16_model()
vgg16_model.load_weights(vgg16_model_path)
print("✅ VGG16 Model Loaded Successfully!")

# --------------------------- #
# 🔹 Function: Preprocess Image for VGG16
# --------------------------- #
def preprocess_for_vgg16(image):
    image = image.resize((224, 224))  # Resize image
    image = np.array(image) / 255.0     # Normalize
    image = np.expand_dims(image, axis=0)  # Expand dims for model
    return image

# --------------------------- #
# 🔹 Function: Classify Image Using VGG16
# --------------------------- #
def classify_image(image_path):
    image = Image.open(image_path)  # Open image
    processed_img = preprocess_for_vgg16(image)  # Preprocess for VGG16
    predictions = vgg16_model.predict(processed_img)  # Predict

    class_id = np.argmax(predictions)
    confidence = predictions[0][class_id]
    
    # Use the same explicit class order
    label = f"{classes_order[class_id]} ({confidence:.2f})"
    
    return label

# --------------------------- #
# 🔹 Function to Open File Dialog and Select Image
# --------------------------- #
def select_image():
    root = tk.Tk()
    root.withdraw()  # Hide the root window
    image_path = filedialog.askopenfilename(title="Select Image", filetypes=[
        ("Image files", "*.jpg *.jpeg *.png *.JPG *.JPEG *.PNG"), 
        ("All files", "*.*")
    ])
    return image_path

# --------------------------- #
# 🔹 Function to Display the Classification Result
# --------------------------- #
def show_classification_result(image_path):
    result_label.config(text="Processing... Please wait.", fg="black")
    
    # Run classification in a background thread to avoid blocking UI
    threading.Thread(target=run_classification, args=(image_path,)).start()

# --------------------------- #
# 🔹 Function to Run Classification in the Background
# --------------------------- #
def run_classification(image_path):
    try:
        # Classify the uploaded image
        result = classify_image(image_path)
        
        # Update the result label in the main thread
        result_label.config(text=f"Prediction: {result}", fg="green")
        
    except Exception as e:
        # In case of error, display the error message
        result_label.config(text=f"Error: {str(e)}", fg="red")

# --------------------------- #
# 🔹 Function to Load and Display Image in Tkinter
# --------------------------- #
def load_image(image_path):
    image = Image.open(image_path)
    image.thumbnail((400, 400))  # Resize for better display
    img_tk = ImageTk.PhotoImage(image)
    
    # Keep a reference of the image to prevent it from being garbage collected
    preview_label.image = img_tk  
    preview_label.config(image=img_tk)

# --------------------------- #
# 🔹 Create the Tkinter GUI
# --------------------------- #
window = tk.Tk()
window.title("Image Classification")
window.geometry("600x600")

# Create an upload button
upload_button = tk.Button(window, text="Upload Image", font=("Helvetica", 14), command=lambda: on_upload())
upload_button.pack(pady=10)

# Label to display the selected image preview
preview_label = tk.Label(window)
preview_label.pack(pady=20)

# Label for the classification result
result_label = tk.Label(window, text="Prediction: None", font=("Helvetica", 14), fg="blue")
result_label.pack(pady=20)

# --------------------------- #
# 🔹 Upload Button Logic
# --------------------------- #
def on_upload():
    image_path = select_image()
    if image_path:
        load_image(image_path)
        show_classification_result(image_path)
    else:
        messagebox.showerror("Error", "No image selected. Please upload an image.")

# Run the Tkinter event loop
window.mainloop()
# Out:
# Found 1695 images belonging to 6 classes.
# Found 452 images belonging to 6 classes.
# Training class indices: {'10_new': 0, '20_new': 1, '50_new': 2, '100_new': 3, '200_new': 4, '500_new': 5}
# Validation class indices: {'10_new': 0, '20_new': 1, '50_new': 2, '100_new': 3, '200_new': 4, '500_new': 5}
# Training VGG16 Model... 🚀
# 2025-02-22 06:14:26.176235: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /home/user/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# Copying files: 531 files [11:38,  1.32s/ files]
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 436s 8s/step - accuracy: 0.2006 - loss: 1.8635 - val_accuracy: 0.4889 - val_loss: 1.5416
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 441s 8s/step - accuracy: 0.4635 - loss: 1.5033 - val_accuracy: 0.6239 - val_loss: 1.2913
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 444s 8s/step - accuracy: 0.5703 - loss: 1.2782 - val_accuracy: 0.7190 - val_loss: 1.0900
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 443s 8s/step - accuracy: 0.6677 - loss: 1.0672 - val_accuracy: 0.7522 - val_loss: 0.9216
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 444s 8s/step - accuracy: 0.7191 - loss: 0.9250 - val_accuracy: 0.8296 - val_loss: 0.7749
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.7800 - loss: 0.7766 - val_accuracy: 0.8584 - val_loss: 0.6596
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 441s 8s/step - accuracy: 0.8212 - loss: 0.6648 - val_accuracy: 0.8584 - val_loss: 0.5749
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.8406 - loss: 0.5630 - val_accuracy: 0.8496 - val_loss: 0.5388
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 446s 8s/step - accuracy: 0.8400 - loss: 0.5489 - val_accuracy: 0.9027 - val_loss: 0.4279
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 454s 9s/step - accuracy: 0.8759 - loss: 0.4547 - val_accuracy: 0.9137 - val_loss: 0.3957
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 456s 9s/step - accuracy: 0.9176 - loss: 0.3822 - val_accuracy: 0.9204 - val_loss: 0.3470
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 451s 9s/step - accuracy: 0.8970 - loss: 0.3613 - val_accuracy: 0.9314 - val_loss: 0.3012
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 459s 9s/step - accuracy: 0.9146 - loss: 0.3301 - val_accuracy: 0.9358 - val_loss: 0.2910
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 454s 9s/step - accuracy: 0.9235 - loss: 0.2981 - val_accuracy: 0.9513 - val_loss: 0.2524
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 453s 9s/step - accuracy: 0.9257 - loss: 0.2931 - val_accuracy: 0.9646 - val_loss: 0.2200
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 451s 9s/step - accuracy: 0.9394 - loss: 0.2503 - val_accuracy: 0.9469 - val_loss: 0.2118
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 457s 9s/step - accuracy: 0.9460 - loss: 0.2346 - val_accuracy: 0.9757 - val_loss: 0.1904
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 449s 8s/step - accuracy: 0.9576 - loss: 0.2025 - val_accuracy: 0.9690 - val_loss: 0.1657
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 451s 9s/step - accuracy: 0.9557 - loss: 0.1934 - val_accuracy: 0.9580 - val_loss: 0.1575
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.9680 - loss: 0.1733 - val_accuracy: 0.9735 - val_loss: 0.1390
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 449s 8s/step - accuracy: 0.9825 - loss: 0.1446 - val_accuracy: 0.9889 - val_loss: 0.1206
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 450s 8s/step - accuracy: 0.9601 - loss: 0.1607 - val_accuracy: 0.9779 - val_loss: 0.1259
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 446s 8s/step - accuracy: 0.9677 - loss: 0.1518 - val_accuracy: 0.9757 - val_loss: 0.1155
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 450s 8s/step - accuracy: 0.9714 - loss: 0.1394 - val_accuracy: 0.9845 - val_loss: 0.1002
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 450s 8s/step - accuracy: 0.9757 - loss: 0.1108 - val_accuracy: 0.9889 - val_loss: 0.0926
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 447s 8s/step - accuracy: 0.9832 - loss: 0.1077 - val_accuracy: 0.9823 - val_loss: 0.0914
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 452s 9s/step - accuracy: 0.9886 - loss: 0.0951 - val_accuracy: 0.9867 - val_loss: 0.0785
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 447s 8s/step - accuracy: 0.9858 - loss: 0.0908 - val_accuracy: 0.9978 - val_loss: 0.0664
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.9867 - loss: 0.0890 - val_accuracy: 0.9912 - val_loss: 0.0656
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 445s 8s/step - accuracy: 0.9969 - loss: 0.0773 - val_accuracy: 0.9978 - val_loss: 0.0547
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ VGG16 Model saved as 'vgg16_model.h5'.
# ✅ VGG16 Model Loaded Successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
